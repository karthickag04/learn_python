# %%
print("Welcome to python")
# Out:
# Welcome to python

# %%
# arithmetic operations:

'''
Arithmetic operations are used to perform mathematical calculations.
The basic arithmetic operations include:
1. Addition (+): Adds two numbers together.
2. Subtraction (-): Subtracts one number from another.
3. Multiplication (*): Multiplies two numbers together.
4. Division (/): Divides one number by another.
5. Modulus (%): Returns the remainder of a division operation.
6. Exponentiation (**): Raises a number to the power of another number.
7. Floor Division (//): Divides one number by another and rounds down to the nearest whole number.
'''
# Out:
# '\nArithmetic operations are used to perform mathematical calculations.\nThe basic arithmetic operations include:\n1. Addition (+): Adds two numbers together.\n2. Subtraction (-): Subtracts one number from another.\n3. Multiplication (*): Multiplies two numbers together.\n4. Division (/): Divides one number by another.\n5. Modulus (%): Returns the remainder of a division operation.\n6. Exponentiation (**): Raises a number to the power of another number.\n7. Floor Division (//): Divides one number by another and rounds down to the nearest whole number.\n'

# %%
first_number = 11
second_number = 2
print("Addition:", first_number + second_number)  # Output: 15
print("Subtraction:", first_number - second_number)  # Output: 5
print("Multiplication:", first_number * second_number)  # Output: 50
print("Division:", first_number / second_number)  # Output: 2.0
print("Modulus:", first_number % second_number)  # Output: 0
print("Exponentiation:", first_number ** second_number)  # Output: 100000
print("Floor Division:", first_number // second_number)  # Output: 2
# Out:
# Addition: 13
# Subtraction: 9
# Multiplication: 22
# Division: 5.5
# Modulus: 1
# Exponentiation: 121
# Floor Division: 5

# %%
def addition(first_number, second_number):
    print("Addition:", first_number + second_number)

# %%
addition(22,2)
# Out:
# Addition: 24

# %%
def subtraction(first_number, second_number):
    print("Subtraction:", first_number - second_number)

# %%
subtraction(22,2)
# Out:
# Subtraction: 20

# %%
def multiplication(first_number, second_number):
    print("Multiplication:", first_number * second_number)
def division(first_number, second_number):
    print("Division:", first_number / second_number)
def modulus(first_number, second_number):
    print("Modulus:", first_number % second_number)
def exponentiation(first_number, second_number):
    print("Exponentiation:", first_number ** second_number)
def floor_division(first_number, second_number):
    print("Floor Division:", first_number // second_number)

# %%
addition(11, 2)
addition(112, 2)
addition(112, 22)
addition(1122, 2)
# Out:
# Addition: 13
# Addition: 114
# Addition: 134
# Addition: 1124
