# %% [markdown]
# ## Encapsulation:
#     - Using getter and setter methods to access and modify the private attribute __course_list

# %%
class Gtec:
    course_list01 = ["Python", "Java", "C++", "JavaScript", "HTML", "CSS"]
    __course_list = ["Python", "Java", "C++", "JavaScript", "HTML", "CSS"]

    # def __init__(self, course_list):
    #     self.__course_list = course_list


    def get_course_list(self):
        return Gtec.__course_list
    
    def set_course_list(self, course_list):
        Gtec.__course_list.append(course_list)

# %%
gt = Gtec()
# Gtec.course_list01
# gt.course_list01
print(gt.get_course_list())
gt.set_course_list("SQL")
print(gt.get_course_list())
# Out:
# ['Python', 'Java', 'C++', 'JavaScript', 'HTML', 'CSS']
# ['Python', 'Java', 'C++', 'JavaScript', 'HTML', 'CSS', 'SQL']

# %%
class Gtec:
    course_list01 = ["Python", "Java", "C++", "JavaScript", "HTML", "CSS"]
    __course_list = ["Python", "Java", "C++", "JavaScript", "HTML", "CSS"]

    # def __init__(self, course_list):
    #     self.__course_list = course_list


    def get_course_list(self):
        return Gtec.__course_list
    
    def set_course_list(self, course_list):
        Gtec.__course_list.append(course_list)

class Trainer(Gtec):
    __Trainer_name = "John Doe"

    def get_trainer_name(self):
        return Trainer.__Trainer_name


    def get_course_list(self):
        all_trainer_taking_courses = []
        old_gtec_courses = super().get_course_list()

        for course in old_gtec_courses:
            if course == "Python" or course == "Java":
                # old_gtec_courses.remove(course)
                continue
            
            else:
                all_trainer_taking_courses.append(course)

        return all_trainer_taking_courses
    
    def set_course_list(self, course_list):
        pass

# %%
gt = Gtec()
tr = Trainer()
# print(tr.get_course_list())
# tr.set_course_list("SQL")
print(tr.get_course_list())
print(gt.get_course_list())
# Out:
# ['C++', 'JavaScript', 'HTML', 'CSS']
# ['Python', 'Java', 'C++', 'JavaScript', 'HTML', 'CSS']

# %%
class TMYS:
    def welcome(self):
        print("Welcome to TMYS")

# %%
class student(Gtec, TMYS):
    pass

# %%
student1 = student()
student1.welcome()
student1.get_course_list()
# Out:
# Welcome to TMYS
# ['Python', 'Java', 'C++', 'JavaScript', 'HTML', 'CSS']
