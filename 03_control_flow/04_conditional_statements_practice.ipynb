# %%
# if else
# if elif else
# nested if else

# %%
if True:
    print("100 is equal to 100")
else:
    print("100 is not equal to 100")
# Out:
# 100 is not equal to 100

# %%
# make examples for all the comparison operators
# ==, !=, >, <, >=, <=

x = 10
y = 20

if x == y:
    print("x is equal to y")
else:
    print("x is not equal to y")

if x != y:
    print("x is not equal to y")
else:
    print("x is equal to y")

if x > y:
    print("x is greater than y")
else:
    print("x is not greater than y")

if x < y:
    print("x is less than y")
else:
    print("x is not less than y")

if x >= y:
    print("x is greater than or equal to y")
else:
    print("x is not greater than or equal to y")

if x <= y:
    print("x is less than or equal to y")
else:
    print("x is not less than or equal to y")

# %%
# make examples for all the comparison operators with logical operators
# ==, !=, >, <, >=, <=

x = 10
y = 20
z = 15

if x == 10 and y == 20 and z == 15:
    print("x is equal to 10 and y is equal to 20")

if x != y and x < y:
    print("x is not equal to y and x is less than y")

if x > z or y > z:
    print("either x is greater than z or y is greater than z")

if x < z or y < z:
    print("either x is less than z or y is less than z")

if x >= 10 and y >= 10:
    print("x and y are both greater than or equal to 10")

if not x == y and x <= y:
    print("x is not equal to y and x is less than or equal to y")

# %%
# make examples for all the comparison operators with logical operators
# ==, !=, >, <, >=, <=

x = 109
y = 20
z = 15

if x == 10 and y == 20 and z == 15:
    print("x is equal to 10 and y is equal to 20")
elif x != y and x < y:
    print("x is not equal to y and x is less than y")
elif x > z or y > z:
    print("either x is greater than z or y is greater than z")
elif x < z or y < z:
    print("either x is less than z or y is less than z")
elif x >= 10 and y >= 10:
    print("x and y are both greater than or equal to 10")
elif not x == y and x <= y:
    print("x is not equal to y and x is less than or equal to y")
# Out:
# either x is greater than z or y is greater than z

# %%
# nested if else

x = 109
y = 20
z = 15

if x > y:
     if x > z:
        print("x is greater than y and z")
     else:
        if x == z:
           print("x is greater than y and equal to z")
        else:
            print("x is greater than y and less than z")
    
else:
    print("x is not greater than y")
# Out:
# x is greater than y and z
