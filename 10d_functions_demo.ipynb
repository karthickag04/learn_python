# %%
def addition_program():
    x = 10
    y = 20
    print("The sum is:", x + y)

# %%
addition_program()
# Out:
# The sum is: 30
# The sum is: 30
# The sum is: 30
# The sum is: 30

# %%
def addition_program(x , y, z=10):
    print("The sum is:", x + y + z)

# %%
addition_program(22,320)
# Out:
# The sum is: 402

# %%
def addition_program(x , y):
  return x + y

# %%
result = addition_program(22,22)

# %%
print(result)
# Out:
# 44

# %%
if result > 50:
    print("The result is greater than 50")
else:
    print("The result is 50 or less")
# Out:
# The result is 50 or less

# %%
program_additon =lambda a, b: a + b

# %%
program_additon(10,20)
# Out:
# 30

# %%
program_additon_with_conditonal_Check =lambda a, b: "A is higher" if a > b else "B is higher or equal"

# %%
program_additon_with_conditonal_Check(10,20)
# Out:
# 'B is higher or equal'

# %%
example_lambda_With_for_loop = lambda numbers: [number+1000 for number in numbers]

# %%
numbers = [1,2,3,4,5]
for number in numbers:
    print(number + 1000)
# Out:
# 1001
# 1002
# 1003
# 1004
# 1005

# %%
example_lambda_With_for_loop(numbers)
# Out:
# [1001, 1002, 1003, 1004, 1005]

# %%
first_name= "john"
list03 = [14,24,33,34,53]
# len(first_name)
len(list03)
# Out:
# 5

# %%
list03 = [14,24,33,34,53]

# practice on while

i = 0
while i < len(list03):
    print(list03[i] + 1000)
    i += 1 # i = 0 + 1
