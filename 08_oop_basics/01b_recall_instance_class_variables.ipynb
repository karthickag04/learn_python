# %%
class TrainingInstitute:

    list_of_institutes = ["Tech Academy", "Code School", "Data Camp", "Dev Institute"]
    _list_of_institutes01 = ["Tech Academy", "Code School", "Data Camp", "Dev Institute"]
    __list_of_institutes02 = ["Tech Academy", "Code School", "Data Camp", "Dev Institute"]
   

    def __init__(self,courses):
        self.courses = courses
        # self.institute_location()
    
    def list_courses(self):
        # courses = ["Python Programming", "Data Science", "Web Development", "Machine Learning"]
        self.institute_location()
        return self.courses, self.location , self.list_of_institutes, TrainingInstitute.list_of_institutes


    def check_course(self, course_name):
        if course_name in self.courses:
           
            return f"{course_name} is available. under the location {self.location}"
        else:
            return f"{course_name} is not available."

    def return_location(self):
        return self.location
    
    def institute_location(self):
        self.location = "123 Main St, Anytown, USA"
        return self.location

# %%
TI = TrainingInstitute(["Python Programming", "Data Science", "Web Development", "Machine Learning", "Cloud Computing"])

# %%
print(TI.list_courses())
# Out:
# (['Python Programming', 'Data Science', 'Web Development', 'Machine Learning', 'Cloud Computing'], '123 Main St, Anytown, USA', ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute'], ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute'])

# %%
TI.check_course("Data Science")
# Out:
# 'Data Science is available. under the location 123 Main St, Anytown, USA'

# %%
TI01 = TrainingInstitute(["Python Programming", "Data Science", "Web Development", "Machine Learning", "Cloud Computing", "Cybersecurity", "DevOps", "AI Fundamentals"])

# %%
TI.list_courses()
# Out:
# (['Python Programming',
#   'Data Science',
#   'Web Development',
#   'Machine Learning',
#   'Cloud Computing'],
#  '123 Main St, Anytown, USA',
#  ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute'],
#  ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute'])

# %%
TI01.list_courses()
# Out:
# (['Python Programming',
#   'Data Science',
#   'Web Development',
#   'Machine Learning',
#   'Cloud Computing',
#   'Cybersecurity',
#   'DevOps',
#   'AI Fundamentals'],
#  '123 Main St, Anytown, USA',
#  ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute'],
#  ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute'])

# %%
TrainingInstitute.list_of_institutes
# Out:
# ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute']

# %%
TI.return_location()
# Out:
# '123 Main St, Anytown, USA'

# %%
TI.location= "456 Elm St, Othertown, USA"

# %%
TI.return_location()
# Out:
# '456 Elm St, Othertown, USA'

# %%
TI.return_location()
# Out:
# '123 Main St, Anytown, USA'

# %%
TI.check_course("Data Science")
# Out:
# 'Data Science is available. under the location 456 Elm St, Othertown, USA'

# %%
TI.check_course("Data Science")
# Out:
# 'Data Science is available. under the location 123 Main St, Anytown, USA'

# %%
TI.list_courses()
# Out:
# (['Python Programming',
#   'Data Science',
#   'Web Development',
#   'Machine Learning',
#   'Cloud Computing'],
#  '123 Main St, Anytown, USA',
#  ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute'],
#  ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute'])

# %%
class TrainingInstitute:

   list_of_institutes = ["Tech Academy", "Code School", "Data Camp", "Dev Institute"]
   _list_of_institutes01 = ["Tech Academy", "Code School", "Data Camp", "Dev Institute"]
   __list_of_institutes02 = ["Tech Academy", "Code School", "Data Camp", "Dev Institute"]

   def __init__(self):
       self.institute_location = "123 Main St, Anytown, USA"
       self._institute_location = "123 Main St, Anytown, USA 01"
       self.__institute_location = "123 Main St, Anytown, USA 02"
   
   def printmsg(self):
       print("Welcome to the Training Institute")
       print(self.list_of_institutes)
       print(self._list_of_institutes01)
       print(self.__list_of_institutes02)
       print(TrainingInstitute.__list_of_institutes02)
       TrainingInstitute.__list_of_institutes02 = "new value"
       print(TrainingInstitute.__list_of_institutes02)

   def return_location(self):
       return self.__institute_location 
   def return_institutes(self):
       return self.__list_of_institutes02

# %%
TrainingInstitute.list_of_institutes
# Out:
# ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute']

# %%
TrainingInstitute._list_of_institutes01
# Out:
# ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute']

# %%
TrainingInstitute.__list_of_institutes02
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 TrainingInstitute.__list_of_institutes02
#
# AttributeError: type object 'TrainingInstitute' has no attribute '__list_of_institutes02'

# %%
ti00 = TrainingInstitute()
# ti00.printmsg()

# %%
TrainingInstitute.list_of_institutes = "updated list of institutes"

# %%
ti00.printmsg()
# Out:
# Welcome to the Training Institute
# updated list of institutes
# ['Tech Academy', 'Code School', 'Data Camp', 'Dev Institute']
# new value
# new value
# new value

# %%
ti00.institute_location
# Out:
# '123 Main St, Anytown, USA'

# %%
ti00._institute_location
# Out:
# '123 Main St, Anytown, USA 01'

# %%
ti00.__institute_location
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 ti00.__institute_location
#
# AttributeError: 'TrainingInstitute' object has no attribute '__institute_location'

# %%
# ti00.return_institutes()
ti00.return_location()
# Out:
# '123 Main St, Anytown, USA 02'
